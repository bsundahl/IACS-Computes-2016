# %% [markdown]
# # Folium

# %% [markdown]
# Folium is part of the pip package installer. Installation is easy. Simply open up a terminal and then type
#
#   "pip install folium"
#
# and that should do it.

# %%
import folium

# %%
help(folium)
# Out:
# Help on package folium:
#
# NAME
#     folium - # -*- coding: utf-8 -*-
#
# FILE
#     /Users/bryansundahl/anaconda/lib/python2.7/site-packages/folium/__init__.py
#
# PACKAGE CONTENTS
#     colormap
#     element
#     features
#     folium
#     map
#     plugins (package)
#     six
#     utilities
#
# CLASSES
#     folium.element.Element(__builtin__.object)
#         folium.features.Vega
#         folium.map.Popup
#     folium.element.MacroElement(folium.element.Element)
#         folium.features.ClickForMarker
#         folium.features.DivIcon
#         folium.features.LatLngPopup
#         folium.features.MultiPolyLine
#         folium.features.PolyLine
#         folium.map.FitBounds
#         folium.map.Icon
#             folium.features.CustomIcon
#         folium.map.LayerControl
#         folium.map.Marker
#             folium.features.CircleMarker
#             folium.features.RegularPolygonMarker
#     folium.map.Layer(folium.element.MacroElement)
# ...

# %%
map_osm = folium.Map(location=[45.5236, -122.6750])
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
from folium import plugins
import numpy as np

data = (np.random.normal(size=(100, 3)) *
        np.array([[1, 1, 1]]) +
        np.array([[48, 5, 1]])).tolist()


mapa = folium.Map([48., 5.], tiles='stamentoner', zoom_start=6)
mapa.add_children(plugins.HeatMap(data))
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
mapa = folium.Map(location=[45.372, -121.6972], zoom_start=12, tiles='Stamen Terrain')

icon = folium.Icon(color='blue', icon_color='white', icon='cloud',
                   angle=0, prefix='glyphicon')
p0 = folium.Marker([45.3788, -121.6625], popup='Mt. Hood Meadows', icon=icon)

icon = folium.Icon(color='green')
p1 = folium.Marker([45.3711, -121.7113], popup='Timberline Lodge', icon=icon)

p2 = folium.Marker([45.3700, -121.6823], popup='simple')

mapa.add_children(p0)
mapa.add_children(p1)
mapa.add_children(p2)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
mapa = folium.Map([43,-100], zoom_start=4)
folium.GeoJson('us-states.json').add_to(mapa)
mapa
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-0d4981d4289c> in <module>()
#       1 mapa = folium.Map([43,-100], zoom_start=4)
#       2 folium.GeoJson('us-states.json').add_to(mapa)
# ----> 3 folium.GeoJson(open('./data/us-states.json')).add_to(mapa)
#       4 mapa
#
# IOError: [Errno 2] No such file or directory: './data/us-states.json'
